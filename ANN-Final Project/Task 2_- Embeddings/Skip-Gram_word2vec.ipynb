# %% [markdown]
# # Skip-gram word2vec
#
# https://books.google.co.in/books?id=qkFPDwAAQBAJ&pg=PA142&lpg=PA142&dq=train_graph+%3D+tf.Graph()+with+train_graph.as_default():&source=bl&ots=U-LfCqBOUC&sig=ACfU3U0nEeLkdFfFZaIhx6LAlGL_gPfaEA&hl=en&sa=X&ved=2ahUKEwiyuf_-5J7qAhVwIbcAHV1dCs0Q6AEwCXoECAsQAQ#v=onepage&q=train_graph%20%3D%20tf.Graph()%20with%20train_graph.as_default()%3A&f=false
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
# %tensorflow_version 1.x
import numpy as np
import tensorflow as tf

import utils
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:33, 334kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
import numpy as np

threshold = 1e-5
word_counts = Counter(int_words)
#print(list(word_counts.items())[0])  # dictionary of int_words, how many times they appear

total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
# discard some frequent words, according to the subsampling equation
# create a new list of words for training
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

print(train_words[:30])
# Out:
# [5233, 3133, 58, 155, 741, 476, 10571, 27349, 15067, 58112, 854, 3580, 194, 10712, 1324, 454, 2731, 362, 371, 1423, 2757, 567, 7088, 320, 44611, 186, 5233, 1134, 2621, 8983]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = words[start:idx] + words[idx+1:stop+1]
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding)))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,biases=softmax_b,
                                      labels=labels, inputs=embed,
                                      num_sampled = n_sampled,
                                      num_classes = n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.8877 0.0482 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.6699 0.0313 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.4385 0.0310 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.4291 0.0313 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.2235 0.0314 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.0676 0.0311 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 16.9400 0.0312 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.9470 0.0310 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.7298 0.0314 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.6055 0.0310 sec/batch
# Nearest to other: formalised, roaring, armigerous, letsie, brassiere, humiliated, waldman, kuttner,
# Nearest to new: arghun, sharkey, dunk, advancements, farah, dental, sadler, awarding,
# Nearest to than: preside, xls, tux, aldrin, smelted, manipulates, detachments, longtime,
# Nearest to is: cei, variability, battersea, hellenism, immune, legislature, kosmos, fortitude,
# Nearest to called: jaipur, habakkuk, concept, brink, kinetics, picts, queensberry, bc,
# Nearest to after: ki, cognition, colliding, necromancer, olbers, miserere, incisors, boosted,
# Nearest to where: maibock, caveats, roundaboutness, spout, runge, ljubljana, savoy, meagre,
# Nearest to who: molasses, interbase, pricewaterhousecoopers, zel, rash, licence, pillar, rapunzel,
# Nearest to behind: lyman, gastroenterology, esperanza, tice, vilified, westview, marcius, renato,
# Nearest to writers: impacts, toyotomi, conditional, ormond, donnie, synge, boyce, booklet,
# Nearest to construction: goode, filmography, ogden, stupor, membered, barnes, mismanaged, seci,
# Nearest to grand: immanence, isdb, depths, schizophrenic, fledging, nutritional, dpi, paste,
# Nearest to stage: toulon, cures, perestroika, invulnerability, interjection, buffs, maserati, jabr,
# Nearest to scale: netanyahu, foodcrops, streisand, culhwch, voters, bait, massed, duryodhana,
# Nearest to paris: limestones, timezone, halleck, granaries, nans, ness, dirks, complain,
# Nearest to animals: mandating, broadband, israeli, decoding, oak, offshoot, wco, melanin,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.4626 0.0322 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.4172 0.0311 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.2792 0.0310 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.0750 0.0312 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.0260 0.0313 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.9497 0.0314 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.7894 0.0312 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7299 0.0314 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.5913 0.0315 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5758 0.0312 sec/batch
# Nearest to other: formalised, roaring, armigerous, letsie, brassiere, kuttner, waldman, humiliated,
# Nearest to new: arghun, dental, dunk, sharkey, farah, chancellorsville, advancements, awarding,
# Nearest to than: preside, tux, aldrin, manipulates, detachments, longtime, smelted, xls,
# Nearest to is: variability, cei, legislature, hellenism, fortitude, immune, battersea, realists,
# Nearest to called: jaipur, kinetics, concept, brink, bc, queensberry, picts, habakkuk,
# Nearest to after: ki, cognition, colliding, necromancer, olbers, boosted, incisors, inman,
# Nearest to where: maibock, spout, caveats, ljubljana, roundaboutness, savoy, runge, titusville,
# Nearest to who: molasses, interbase, pricewaterhousecoopers, rash, zel, democratization, licence, sec,
# Nearest to behind: lyman, gastroenterology, esperanza, tice, vilified, westview, renato, lactation,
# Nearest to writers: impacts, toyotomi, conditional, ormond, donnie, boyce, synge, shilling,
# Nearest to construction: goode, filmography, seci, stupor, barnes, membered, mismanaged, ogden,
# Nearest to grand: immanence, isdb, depths, schizophrenic, fledging, nutritional, hyrum, dpi,
# Nearest to stage: toulon, cures, perestroika, invulnerability, yellowish, interjection, jabr, buffs,
# Nearest to scale: foodcrops, netanyahu, culhwch, streisand, completely, bait, phantom, duryodhana,
# Nearest to paris: limestones, halleck, timezone, granaries, dirks, ness, curved, redesign,
# Nearest to animals: mandating, wco, broadband, israeli, oak, offshoot, decoding, brigham,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4169 0.0324 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.3031 0.0313 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.1935 0.0313 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.1058 0.0312 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.9775 0.0313 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.9205 0.0315 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.8172 0.0311 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.7033 0.0315 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.5971 0.0313 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.5077 0.0316 sec/batch
# Nearest to other: formalised, roaring, armigerous, kuttner, letsie, eavesdropper, humiliated, brassiere,
# Nearest to new: arghun, dental, dunk, chancellorsville, farah, sharkey, egyptologists, kangol,
# Nearest to than: preside, aldrin, tux, manipulates, longtime, detachments, smelted, countable,
# Nearest to is: variability, hellenism, legislature, fortitude, cei, stomach, battersea, blu,
# Nearest to called: jaipur, concept, brink, bc, kinetics, picts, queensberry, brittonum,
# Nearest to after: ki, cognition, colliding, boosted, olbers, necromancer, miserere, limitation,
# Nearest to where: maibock, spout, ljubljana, roundaboutness, caveats, stapleton, savoy, phoenix,
# Nearest to who: molasses, interbase, zel, rash, pricewaterhousecoopers, democratization, sec, pillar,
# Nearest to behind: lyman, gastroenterology, tice, esperanza, vilified, renato, westview, lactation,
# Nearest to writers: impacts, conditional, toyotomi, ormond, synge, donnie, achievement, shilling,
# Nearest to construction: goode, filmography, seci, barnes, membered, stupor, miming, mismanaged,
# Nearest to grand: immanence, isdb, depths, fledging, nutritional, schizophrenic, hyrum, dpi,
# Nearest to stage: toulon, cures, perestroika, yellowish, interjection, invulnerability, buffs, jabr,
# Nearest to scale: culhwch, foodcrops, netanyahu, streisand, completely, bait, duryodhana, restless,
# Nearest to paris: limestones, timezone, halleck, curved, redesign, dirks, ness, granaries,
# Nearest to animals: mandating, offshoot, oak, israeli, wco, decoding, broadband, brigham,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4484 0.0323 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.3678 0.0311 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.2207 0.0311 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1168 0.0314 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.0160 0.0311 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 14.0239 0.0312 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.8762 0.0312 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8859 0.0312 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.7420 0.0313 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.6549 0.0313 sec/batch
# Nearest to other: formalised, armigerous, roaring, kuttner, letsie, waldman, philosophic, brassiere,
# Nearest to new: arghun, kangol, chancellorsville, dunk, dental, farah, tulip, hinders,
# Nearest to than: preside, tux, detachments, aldrin, longtime, manipulates, smelted, mujahideen,
# Nearest to is: variability, legislature, hellenism, fortitude, luce, codename, stomach, rivalling,
# Nearest to called: jaipur, concept, brink, ller, kinetics, bc, queensberry, brittonum,
# Nearest to after: ki, cognition, colliding, olbers, boosted, necromancer, incisors, limitation,
# Nearest to where: maibock, spout, ljubljana, roundaboutness, meagre, caveats, phoenix, stapleton,
# Nearest to who: molasses, interbase, zel, rash, pricewaterhousecoopers, babel, pillar, piercy,
# Nearest to behind: lyman, tice, gastroenterology, esperanza, vilified, marcius, mazda, renato,
# Nearest to writers: impacts, conditional, toyotomi, donnie, synge, ormond, boyce, achievement,
# Nearest to construction: goode, filmography, stupor, barnes, miming, seci, mismanaged, membered,
# Nearest to grand: immanence, depths, isdb, fledging, dpi, schizophrenic, nutritional, barbecue,
# Nearest to stage: toulon, cures, perestroika, invulnerability, interjection, yellowish, jabr, stews,
# Nearest to scale: culhwch, completely, foodcrops, netanyahu, bait, duryodhana, perez, pershing,
# Nearest to paris: limestones, halleck, curved, dirks, ness, timezone, granaries, complain,
# Nearest to animals: israeli, mandating, offshoot, oak, decoding, melanin, wco, brigham,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.6272 0.0326 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.4764 0.0315 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.2505 0.0314 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3202 0.0316 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.2290 0.0313 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.1970 0.0312 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.1024 0.0234 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9448 0.0321 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.9188 0.0323 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.7281 0.0323 sec/batch
# Nearest to other: formalised, roaring, armigerous, kuttner, letsie, philosophic, waldman, brassiere,
# Nearest to new: chancellorsville, arghun, hinders, televised, kangol, dental, khans, glossary,
# Nearest to than: aldrin, preside, longtime, detachments, tux, manipulates, mujahideen, davis,
# Nearest to is: a, hellenism, rawlings, decades, hume, variability, legislature, codename,
# Nearest to called: concept, ller, jaipur, queensberry, bc, louis, brittonum, kinetics,
# Nearest to after: cognition, ki, colliding, talking, boosted, normalised, necromancer, incisors,
# Nearest to where: ljubljana, spout, phoenix, maibock, stapleton, caveats, shower, savoy,
# Nearest to who: molasses, interbase, zel, rash, babel, vincennes, democratization, pillar,
# Nearest to behind: lyman, esperanza, gastroenterology, tice, vilified, mazda, abroad, marcius,
# Nearest to writers: impacts, conditional, toyotomi, ormond, donnie, synge, achievement, divulge,
# Nearest to construction: goode, filmography, miming, barnes, mismanaged, stupor, missa, wavell,
# Nearest to grand: immanence, isdb, depths, schizophrenic, fledging, dpi, nutritional, barbecue,
# Nearest to stage: toulon, cures, perestroika, interjection, khmer, invulnerability, jabr, yellowish,
# Nearest to scale: foodcrops, culhwch, completely, netanyahu, duryodhana, bait, restless, streisand,
# Nearest to paris: limestones, halleck, granaries, ness, dirks, curved, leverett, complain,
# Nearest to animals: mandating, decoding, oak, israeli, offshoot, melanin, wco, brigham,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.7189 0.0326 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.5995 0.0313 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.3984 0.0315 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.5674 0.0314 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3366 0.0314 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.2506 0.0315 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1389 0.0314 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0394 0.0314 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0085 0.0313 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0217 0.0312 sec/batch
# Nearest to other: formalised, roaring, letsie, philosophic, extraterrestrial, megadeth, kuttner, security,
# Nearest to new: chancellorsville, kangol, arghun, hinders, fulcrum, sufficiently, glossary, dental,
# Nearest to than: aldrin, citric, preside, longtime, patriots, ey, detachments, smelted,
# Nearest to is: a, the, and, of, in, to, as, that,
# Nearest to called: jaipur, ller, brink, bc, concept, brittonum, queensberry, louis,
# Nearest to after: and, normalised, colliding, cognition, adrienne, lethal, vukovar, talking,
# Nearest to where: stapleton, savoy, maibock, ljubljana, shower, facilitate, spout, titusville,
# Nearest to who: rash, zel, babel, interbase, interdisciplinarity, paraclete, democratization, claypool,
# Nearest to behind: lyman, esperanza, tice, gastroenterology, abroad, vilified, store, mazda,
# Nearest to writers: impacts, conditional, shilling, toyotomi, ormond, synge, donnie, achievement,
# Nearest to construction: goode, mismanaged, miming, stupor, missa, filmography, barnes, wavell,
# Nearest to grand: immanence, isdb, depths, schizophrenic, fledging, stylized, dpi, nutritional,
# Nearest to stage: toulon, cures, perestroika, yellowish, mets, interjection, invulnerability, jabr,
# Nearest to scale: foodcrops, culhwch, completely, netanyahu, duryodhana, trakai, bait, councillors,
# Nearest to paris: limestones, halleck, curved, dirks, granaries, ness, complain, timezone,
# Nearest to animals: decoding, mandating, melanin, oak, offshoot, brigham, israeli, outta,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 11.9095 0.0325 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8540 0.0315 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.8284 0.0324 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.6633 0.0323 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.6912 0.0315 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.5642 0.0316 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.3698 0.0315 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.4504 0.0315 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3526 0.0316 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.2511 0.0317 sec/batch
# Nearest to other: to, by, and, of, the, in, zero, from,
# Nearest to new: chancellorsville, kangol, parsimony, nine, sufficiently, seven, spite, s,
# Nearest to than: has, with, it, is, are, this, tasks, which,
# Nearest to is: a, of, the, in, as, and, with, by,
# Nearest to called: at, to, method, by, on, with, in, that,
# Nearest to after: on, first, s, with, and, was, as, the,
# Nearest to where: is, shower, as, not, to, are, prior, hatred,
# Nearest to who: to, in, that, of, from, by, the, crowley,
# Nearest to behind: lyman, esperanza, gastroenterology, tice, abroad, mazda, marcius, store,
# Nearest to writers: impacts, conditional, shilling, ormond, toyotomi, boyce, synge, belles,
# Nearest to construction: mismanaged, goode, miming, sections, diffusing, stupor, wavell, filmography,
# Nearest to grand: immanence, isdb, schizophrenic, fledging, depths, laredo, stylized, jp,
# Nearest to stage: toulon, cures, invulnerability, khmer, jabr, interjection, mets, perestroika,
# Nearest to scale: foodcrops, completely, culhwch, bait, councillors, compared, netanyahu, trakai,
# Nearest to paris: limestones, halleck, granaries, timezone, client, dirks, protectress, deforested,
# Nearest to animals: decoding, mandating, melanin, oak, offshoot, israeli, brigham, furnace,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3385 0.0322 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.1974 0.0314 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9663 0.0313 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.0285 0.0315 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 11.0157 0.0315 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.8695 0.0314 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.9037 0.0316 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8413 0.0313 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6449 0.0315 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.5711 0.0314 sec/batch
# Nearest to other: has, in, some, for, a, from, to, more,
# Nearest to new: nine, an, the, four, seven, at, five, eight,
# Nearest to than: to, it, that, which, has, or, at, with,
# Nearest to is: as, to, of, a, in, for, which, the,
# Nearest to called: a, other, of, to, with, some, in, an,
# Nearest to after: first, s, for, and, in, the, of, as,
# Nearest to where: the, which, is, to, in, it, they, of,
# Nearest to who: of, in, at, the, to, was, a, s,
# Nearest to behind: lyman, gastroenterology, esperanza, tice, marcius, mazda, store, vilified,
# Nearest to writers: conditional, impacts, shilling, synge, belles, ormond, divulge, boyce,
# Nearest to construction: mismanaged, kliper, miming, barnes, stupor, sections, wavell, goode,
# Nearest to grand: isdb, schizophrenic, immanence, depths, laredo, fledging, indus, stylized,
# Nearest to stage: toulon, khmer, cures, mets, invulnerability, yellowish, stews, interjection,
# Nearest to scale: completely, foodcrops, culhwch, compared, councillors, bait, netanyahu, trakai,
# Nearest to paris: limestones, halleck, granaries, deforested, kak, protectress, glottalized, tone,
# Nearest to animals: decoding, mandating, melanin, oak, furnace, brigham, offshoot, israeli,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.6424 0.0325 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.6993 0.0317 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.5083 0.0312 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.4832 0.0311 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.4486 0.0310 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.2032 0.0318 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.4400 0.0315 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2618 0.0314 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.0296 0.0314 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.1062 0.0315 sec/batch
# Nearest to other: the, to, of, also, a, that, in, most,
# Nearest to new: six, one, seven, the, eight, s, of, three,
# Nearest to than: a, the, has, in, as, s, are, it,
# Nearest to is: a, the, to, of, are, as, that, it,
# Nearest to called: and, the, as, that, a, of, with, s,
# Nearest to after: of, s, on, the, by, was, had, were,
# Nearest to where: of, to, the, it, not, which, as, from,
# Nearest to who: of, was, and, the, a, with, in, that,
# Nearest to behind: lyman, gastroenterology, esperanza, tice, mazda, store, marcius, surface,
# Nearest to writers: impacts, conditional, achievement, prescience, shilling, divulge, ormond, toyotomi,
# Nearest to construction: mismanaged, miming, kliper, barnes, sections, stupor, goode, wavell,
# Nearest to grand: schizophrenic, isdb, immanence, indus, fledging, laredo, stylized, depths,
# Nearest to stage: toulon, khmer, deadly, stews, mets, perestroika, invulnerability, interjection,
# Nearest to scale: completely, foodcrops, system, culhwch, compared, metabolize, bait, sharers,
# Nearest to paris: limestones, deforested, tone, halleck, protectress, granaries, kak, glottalized,
# Nearest to animals: decoding, mandating, melanin, furnace, oak, brigham, offshoot, rebels,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.1537 0.0326 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0428 0.0314 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 10.0095 0.0142 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.8660 0.0313 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.8761 0.0315 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.8921 0.0315 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.7256 0.0309 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.7799 0.0313 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.6024 0.0310 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4724 0.0312 sec/batch
# Nearest to other: a, are, for, that, to, of, as, have,
# Nearest to new: one, of, many, in, for, the, that, an,
# Nearest to than: are, to, be, a, so, and, of, the,
# Nearest to is: the, of, and, a, to, in, also, it,
# Nearest to called: are, it, a, other, that, these, for, to,
# Nearest to after: to, was, in, a, by, that, and, had,
# Nearest to where: that, to, was, of, be, a, who, however,
# Nearest to who: of, in, the, to, was, a, from, it,
# Nearest to behind: lyman, store, gastroenterology, esperanza, tice, astronomy, surface, torts,
# Nearest to writers: impacts, thought, conditional, ormond, achievement, there, shilling, daria,
# Nearest to construction: mismanaged, sections, barnes, wavell, kliper, diffusing, verdon, stupor,
# Nearest to grand: isdb, schizophrenic, immanence, laredo, indus, fledging, stylized, philologie,
# Nearest to stage: toulon, deadly, khmer, concourse, mets, perestroika, interjection, hayim,
# Nearest to scale: completely, compared, foodcrops, purchased, culhwch, bait, metabolize, groupware,
# Nearest to paris: limestones, dirks, kak, glottalized, granaries, tone, infiltrators, halleck,
# Nearest to animals: decoding, mandating, melanin, furnace, oak, dam, offshoot, rebels,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.5486 0.0325 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.5137 0.0313 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.3430 0.0312 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1311 0.0315 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.2109 0.0314 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.2612 0.0310 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.2791 0.0311 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.1797 0.0312 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 9.0510 0.0312 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0636 0.0310 sec/batch
# Nearest to other: to, in, the, is, of, has, into, not,
# Nearest to new: the, of, and, in, were, states, although, at,
# Nearest to than: have, is, the, that, of, be, are, to,
# Nearest to is: a, to, not, as, it, in, the, of,
# Nearest to called: is, be, with, of, are, it, other, or,
# Nearest to after: the, in, by, an, was, had, and, to,
# Nearest to where: a, for, with, the, and, an, other, have,
# Nearest to who: of, to, in, been, he, and, had, the,
# Nearest to behind: store, esperanza, lyman, surface, torts, astronomy, tice, activity,
# Nearest to writers: considered, impacts, many, called, conditional, either, such, be,
# Nearest to construction: mismanaged, sections, prozac, wavell, barnes, diffusing, missa, kliper,
# Nearest to grand: isdb, indus, laredo, schizophrenic, stylized, immanence, fledging, garis,
# Nearest to stage: toulon, concourse, reside, mets, accidentally, stews, deadly, khmer,
# Nearest to scale: research, or, compared, foodcrops, has, completely, culhwch, metabolize,
# Nearest to paris: tone, limestones, glottalized, iguana, protectress, deforested, kak, dirks,
# Nearest to animals: oak, decoding, mandating, furnace, melanin, rebels, identified, offshoot,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.0685 0.0323 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0629 0.0312 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.7582 0.0312 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.8348 0.0311 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.8508 0.0312 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.7616 0.0310 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7744 0.0312 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.8872 0.0311 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.5212 0.0312 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.6258 0.0313 sec/batch
# Nearest to other: of, in, and, by, to, it, a, for,
# Nearest to new: and, the, united, was, in, states, of, from,
# Nearest to than: is, be, will, although, been, and, that, have,
# Nearest to is: of, or, the, a, not, as, be, to,
# Nearest to called: is, in, of, a, have, by, has, than,
# Nearest to after: was, had, to, of, and, their, by, as,
# Nearest to where: have, an, a, and, of, any, as, by,
# Nearest to who: of, to, in, not, that, and, as, were,
# Nearest to behind: store, allow, surface, astronomy, swedish, esperanza, handicraft, description,
# Nearest to writers: considered, information, thought, way, each, also, modern, came,
# Nearest to construction: where, mismanaged, good, low, terms, began, prozac, usually,
# Nearest to grand: english, schizophrenic, indus, fledging, laredo, garis, dunbar, immanence,
# Nearest to stage: toulon, reside, ii, accidentally, claim, concourse, perestroika, film,
# Nearest to scale: research, compared, least, believe, difference, used, established, purchased,
# Nearest to paris: limestones, deforested, entire, tone, diatoms, kak, halleck, glottalized,
# Nearest to animals: oak, mandating, decoding, offshoot, rebels, significantly, furnace, mortars,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6713 0.0329 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.4741 0.0312 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.5708 0.0310 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.5648 0.0311 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.3757 0.0310 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.2659 0.0310 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2878 0.0311 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.4155 0.0314 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.3109 0.0314 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2319 0.0314 sec/batch
# Nearest to other: of, to, a, from, that, not, in, as,
# Nearest to new: and, with, of, on, the, in, time, states,
# Nearest to than: even, be, a, are, this, that, not, is,
# Nearest to is: are, a, have, there, this, as, that, to,
# Nearest to called: or, this, to, in, because, an, it, a,
# Nearest to after: of, the, was, in, s, to, on, and,
# Nearest to where: a, is, the, to, in, which, of, it,
# Nearest to who: the, to, in, of, he, and, was, by,
# Nearest to behind: under, also, s, time, more, does, present, including,
# Nearest to writers: considered, see, including, and, way, as, long, work,
# Nearest to construction: under, changes, only, royal, terms, given, this, much,
# Nearest to grand: english, home, schizophrenic, russia, indus, dunbar, official, pre,
# Nearest to stage: end, s, made, including, several, was, work, to,
# Nearest to scale: given, difference, because, compared, result, become, particularly, recent,
# Nearest to paris: entire, nearly, tone, always, though, held, deforested, non,
# Nearest to animals: significantly, offshoot, working, oak, decoding, notion, pain, criticize,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.5239 0.0322 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 8.0034 0.0309 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.3104 0.0307 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1849 0.0309 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 7.9174 0.0311 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.1024 0.0310 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.1010 0.0311 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0288 0.0311 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 8.0458 0.0056 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.9265 0.0312 sec/batch
# Nearest to other: of, to, in, and, the, as, a, there,
# Nearest to new: of, the, in, was, and, has, on, also,
# Nearest to than: are, a, to, of, and, the, as, which,
# Nearest to is: to, of, a, the, and, as, it, in,
# Nearest to called: to, this, of, an, its, a, would, is,
# Nearest to after: was, the, by, in, s, his, and, of,
# Nearest to where: that, to, this, in, a, which, is, would,
# Nearest to who: the, was, to, and, of, his, were, all,
# Nearest to behind: also, is, s, time, for, the, about, well,
# Nearest to writers: works, including, written, work, language, long, modern, together,
# Nearest to construction: given, national, terms, over, country, this, though, course,
# Nearest to grand: july, pre, russia, english, june, year, held, inventor,
# Nearest to stage: original, work, s, as, named, also, death, was,
# Nearest to scale: which, widely, because, difference, any, true, economic, than,
# Nearest to paris: entire, influence, further, they, significant, being, maintain, nearly,
# Nearest to animals: significantly, substantial, reach, notion, made, tradition, working, they,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.9796 0.0322 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.9371 0.0311 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.8198 0.0310 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.9013 0.0311 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.7643 0.0311 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.6124 0.0314 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.7183 0.0322 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6723 0.0319 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.6404 0.0320 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.3417 0.0309 sec/batch
# Nearest to other: to, a, in, and, some, however, this, of,
# Nearest to new: in, by, s, was, and, with, the, their,
# Nearest to than: to, a, of, it, for, the, are, and,
# Nearest to is: are, of, be, or, a, have, the, this,
# Nearest to called: and, have, or, a, to, for, in, of,
# Nearest to after: the, had, was, and, by, before, has, in,
# Nearest to where: of, this, have, an, is, in, for, are,
# Nearest to who: of, the, he, in, were, by, has, was,
# Nearest to behind: and, to, in, for, while, the, its, only,
# Nearest to writers: words, language, written, there, works, considered, origin, ancient,
# Nearest to construction: about, war, in, main, part, until, has, a,
# Nearest to grand: june, official, year, november, seven, events, defeat, english,
# Nearest to stage: began, original, best, which, adopted, by, one, popular,
# Nearest to scale: a, the, in, are, because, well, themselves, to,
# Nearest to paris: become, early, was, became, part, continued, the, iii,
# Nearest to animals: instance, or, conditions, idea, natural, unlike, notion, form,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.4431 0.0320 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.4445 0.0310 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.5524 0.0311 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.5196 0.0313 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.3291 0.0309 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.3777 0.0310 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.4114 0.0311 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.4805 0.0309 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.1872 0.0312 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.2162 0.0315 sec/batch
# Nearest to other: to, and, be, have, some, that, of, has,
# Nearest to new: in, the, was, major, states, on, first, of,
# Nearest to than: the, be, to, some, have, of, is, that,
# Nearest to is: a, be, this, that, can, are, example, not,
# Nearest to called: can, a, other, are, more, to, is, of,
# Nearest to after: the, was, had, took, in, he, before, and,
# Nearest to where: a, this, of, is, be, can, and, other,
# Nearest to who: had, was, the, became, he, and, in, by,
# Nearest to behind: in, a, their, also, much, s, the, to,
# Nearest to writers: written, literature, language, english, contemporary, referred, been, followed,
# Nearest to construction: has, world, over, under, major, industry, and, countries,
# Nearest to grand: english, official, year, start, was, april, january, him,
# Nearest to stage: first, the, was, of, best, in, at, new,
# Nearest to scale: structure, be, some, by, form, may, that, system,
# Nearest to paris: french, george, official, also, ever, was, six, france,
# Nearest to animals: idea, is, as, should, not, instance, can, like,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.2574 0.0331 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.2465 0.0311 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.1938 0.0312 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.2922 0.0312 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.0671 0.0310 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.0461 0.0313 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.1891 0.0310 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.0429 0.0311 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0540 0.0312 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0431 0.0310 sec/batch
# Nearest to other: to, that, a, it, many, as, its, is,
# Nearest to new: of, s, in, the, and, first, was, a,
# Nearest to than: are, that, this, not, have, is, to, there,
# Nearest to is: or, are, that, a, be, this, have, any,
# Nearest to called: a, that, and, this, to, other, an, its,
# Nearest to after: of, was, by, in, s, took, people, the,
# Nearest to where: a, that, is, to, as, it, but, not,
# Nearest to who: in, the, of, and, to, he, s, by,
# Nearest to behind: as, had, once, s, with, move, of, in,
# Nearest to writers: english, literature, modern, s, in, who, early, written,
# Nearest to construction: its, situation, has, important, under, other, the, have,
# Nearest to grand: june, he, saw, was, one, english, s, first,
# Nearest to stage: s, on, for, the, at, of, in, with,
# Nearest to scale: structure, and, thus, than, are, has, a, this,
# Nearest to paris: eight, nine, seven, one, last, four, his, charles,
# Nearest to animals: cause, are, person, necessary, small, body, tend, should,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.0972 0.0321 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.7851 0.0312 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.8713 0.0312 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 7.0047 0.0312 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9886 0.0311 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.8899 0.0312 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.1001 0.0309 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.7191 0.0312 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 6.9051 0.0311 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9762 0.0311 sec/batch
# Nearest to other: to, many, and, for, a, the, their, some,
# Nearest to new: of, in, york, public, on, was, and, the,
# Nearest to than: be, more, for, it, a, are, may, same,
# Nearest to is: are, a, be, this, it, that, to, which,
# Nearest to called: an, and, a, to, the, for, same, it,
# Nearest to after: became, was, in, had, on, of, he, during,
# Nearest to where: an, that, is, the, a, to, be, it,
# Nearest to who: was, in, of, the, and, he, had, against,
# Nearest to behind: the, their, as, in, s, it, with, time,
# Nearest to writers: published, living, literature, births, work, books, authors, press,
# Nearest to construction: to, areas, from, the, at, more, under, of,
# Nearest to grand: established, british, june, was, went, britain, member, opened,
# Nearest to stage: s, for, and, on, with, responsible, an, of,
# Nearest to scale: developing, factors, significantly, more, has, these, significant, developed,
# Nearest to paris: was, france, one, famous, after, until, his, de,
# Nearest to animals: like, completely, are, higher, or, related, does, more,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.7082 0.0322 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7609 0.0311 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.7591 0.0311 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.8110 0.0312 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.9025 0.0311 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6648 0.0277 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.7127 0.0309 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.7674 0.0311 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.6033 0.0312 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.6856 0.0309 sec/batch
# Nearest to other: to, a, and, of, there, such, these, it,
# Nearest to new: in, was, on, s, of, and, by, first,
# Nearest to than: it, be, is, a, more, of, that, only,
# Nearest to is: a, that, of, are, or, an, it, as,
# Nearest to called: a, an, of, in, is, its, such, it,
# Nearest to after: was, in, world, were, at, war, he, had,
# Nearest to where: is, an, that, a, to, not, from, with,
# Nearest to who: he, was, were, in, his, had, of, to,
# Nearest to behind: and, new, the, s, to, on, with, in,
# Nearest to writers: book, authors, life, literary, literature, who, his, works,
# Nearest to construction: industry, major, areas, in, and, heavily, large, extensive,
# Nearest to grand: one, three, seven, nine, two, six, he, won,
# Nearest to stage: s, and, on, in, first, for, original, end,
# Nearest to scale: large, relatively, such, these, which, more, use, as,
# Nearest to paris: france, moved, became, eight, founded, september, five, his,
# Nearest to animals: human, or, instance, factors, these, behavior, conditions, humans,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.6091 0.0322 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.4771 0.0312 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.5600 0.0312 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.5658 0.0310 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5532 0.0310 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.3465 0.0311 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.2934 0.0311 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.3575 0.0310 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4674 0.0311 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.5410 0.0313 sec/batch
# Nearest to other: to, of, as, the, and, have, in, some,
# Nearest to new: of, one, s, the, by, during, in, was,
# Nearest to than: to, have, it, some, such, a, this, is,
# Nearest to is: are, a, have, be, to, this, way, other,
# Nearest to called: is, a, with, have, or, are, its, be,
# Nearest to after: was, the, during, until, were, of, by, and,
# Nearest to where: to, from, more, an, is, other, and, as,
# Nearest to who: had, was, he, his, during, him, were, people,
# Nearest to behind: out, by, at, of, popular, with, while, an,
# Nearest to writers: literature, earliest, english, literary, authors, modern, known, book,
# Nearest to construction: industry, has, facilities, its, during, the, world, large,
# Nearest to grand: one, he, was, november, officer, joined, seven, six,
# Nearest to stage: best, first, by, original, s, the, on, created,
# Nearest to scale: effect, a, it, usually, form, process, may, are,
# Nearest to paris: france, french, founded, louis, german, was, his, paul,
# Nearest to animals: humans, animal, human, or, behavior, may, found, have,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.3671 0.0321 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3744 0.0311 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.3363 0.0311 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4714 0.0311 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.2841 0.0310 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.1623 0.0311 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.2991 0.0309 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.3424 0.0310 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.1784 0.0310 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3221 0.0311 sec/batch
# Nearest to other: of, to, the, an, a, that, has, in,
# Nearest to new: was, first, in, and, the, united, by, during,
# Nearest to than: is, it, be, more, are, an, some, much,
# Nearest to is: be, are, or, a, an, some, it, can,
# Nearest to called: or, is, a, an, other, which, some, that,
# Nearest to after: in, was, the, by, had, did, until, of,
# Nearest to where: an, a, the, other, it, of, is, to,
# Nearest to who: had, in, were, was, of, his, to, the,
# Nearest to behind: with, to, the, from, of, out, few, their,
# Nearest to writers: literature, authors, books, contemporary, was, his, life, writing,
# Nearest to construction: including, local, consists, its, however, industry, the, over,
# Nearest to grand: year, british, new, was, opened, during, won, joined,
# Nearest to stage: first, original, on, successful, cover, it, s, the,
# Nearest to scale: than, used, large, process, changes, less, amount, range,
# Nearest to paris: france, french, de, charles, german, one, november, six,
# Nearest to animals: animal, humans, species, behavior, biological, human, focus, can,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1717 0.0321 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0829 0.0311 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2735 0.0308 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.2288 0.0311 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1670 0.0311 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.1917 0.0310 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2628 0.0312 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.9423 0.0311 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0285 0.0310 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.0193 0.0312 sec/batch
# Nearest to other: not, as, to, or, is, which, have, more,
# Nearest to new: first, world, after, states, on, in, and, s,
# Nearest to than: be, an, a, is, or, have, less, more,
# Nearest to is: are, an, that, be, or, as, this, not,
# Nearest to called: or, are, any, is, all, different, used, as,
# Nearest to after: was, until, had, during, s, became, the, were,
# Nearest to where: a, to, of, the, in, it, which, as,
# Nearest to who: had, his, he, was, against, were, the, themselves,
# Nearest to behind: in, on, made, at, and, s, the, to,
# Nearest to writers: books, literature, book, published, literary, translated, english, story,
# Nearest to construction: for, facilities, the, its, have, it, a, has,
# Nearest to grand: joined, british, opened, was, new, one, home, s,
# Nearest to stage: in, s, and, attention, a, for, to, before,
# Nearest to scale: large, less, than, range, are, have, more, as,
# Nearest to paris: french, st, france, met, george, louis, january, charles,
# Nearest to animals: animal, humans, species, are, conditions, biological, or, occur,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.2348 0.0321 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.1204 0.0310 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.1899 0.0311 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.1296 0.0311 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9547 0.0310 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.1663 0.0308 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 5.9973 0.0310 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.8850 0.0312 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9696 0.0309 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.0358 0.0312 sec/batch
# Nearest to other: a, for, to, this, which, some, are, there,
# Nearest to new: was, on, in, and, first, the, public, s,
# Nearest to than: a, are, for, more, less, other, to, it,
# Nearest to is: a, this, are, be, same, can, different, more,
# Nearest to called: a, are, is, that, to, this, which, any,
# Nearest to after: had, was, war, began, during, became, did, took,
# Nearest to where: it, not, with, which, of, all, an, that,
# Nearest to who: were, had, was, his, he, against, after, did,
# Nearest to behind: s, on, in, it, by, changed, the, at,
# Nearest to writers: authors, published, books, press, literature, literary, influential, births,
# Nearest to construction: the, has, its, to, of, on, it, and,
# Nearest to grand: united, british, opened, britain, year, february, joined, one,
# Nearest to stage: before, films, s, included, film, titled, actors, never,
# Nearest to scale: are, large, small, high, other, significantly, slow, relatively,
# Nearest to paris: france, louis, french, one, after, king, famous, peter,
# Nearest to animals: animal, humans, or, causes, body, are, species, food,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0097 0.0323 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9830 0.0194 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9326 0.0312 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 5.9779 0.0310 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.9286 0.0312 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.9211 0.0312 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9929 0.0313 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.8192 0.0310 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.7760 0.0314 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8356 0.0313 sec/batch
# Nearest to other: of, for, to, has, a, not, as, also,
# Nearest to new: in, the, of, and, was, s, by, at,
# Nearest to than: are, a, more, an, to, it, be, that,
# Nearest to is: are, of, called, as, has, have, same, it,
# Nearest to called: is, are, these, a, that, it, an, different,
# Nearest to after: had, was, before, during, the, who, to, were,
# Nearest to where: an, a, this, as, of, to, but, there,
# Nearest to who: had, he, his, after, was, did, the, against,
# Nearest to behind: with, in, move, more, first, an, back, and,
# Nearest to writers: works, authors, literature, book, literary, story, books, historical,
# Nearest to construction: facilities, has, into, and, its, in, us, at,
# Nearest to grand: one, july, royal, year, united, nine, february, seven,
# Nearest to stage: first, s, in, on, play, best, at, going,
# Nearest to scale: more, are, large, it, a, or, these, below,
# Nearest to paris: french, louis, france, st, charles, moved, seven, march,
# Nearest to animals: animal, humans, characteristics, species, human, ability, causes, or,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.9132 0.0320 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6721 0.0312 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.6162 0.0311 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.7605 0.0311 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7108 0.0311 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8490 0.0322 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.7662 0.0322 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.6575 0.0322 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.6904 0.0313 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.8240 0.0309 sec/batch
# Nearest to other: to, have, a, an, which, some, as, it,
# Nearest to new: the, in, was, by, s, first, on, of,
# Nearest to than: have, is, it, are, more, to, or, a,
# Nearest to is: are, be, this, a, or, an, which, have,
# Nearest to called: is, are, between, be, have, an, different, form,
# Nearest to after: was, had, saw, until, during, his, finally, against,
# Nearest to where: an, of, to, that, a, which, this, the,
# Nearest to who: had, his, he, was, did, him, were, by,
# Nearest to behind: a, the, on, made, in, of, with, and,
# Nearest to writers: literature, bibliography, published, poets, english, works, books, writings,
# Nearest to construction: facilities, has, industry, the, markets, large, industrial, areas,
# Nearest to grand: ii, one, prince, royal, seven, french, st, was,
# Nearest to stage: best, on, first, s, final, play, was, by,
# Nearest to scale: these, higher, nearly, lower, the, consists, this, an,
# Nearest to paris: french, louis, france, st, charles, iii, german, de,
# Nearest to animals: animal, humans, species, biological, behavior, feed, human, plants,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 5.7945 0.0319 sec/batch
# ...
# Nearest to after: during, was, had, back, in, victory, took, once,
# Nearest to where: a, all, at, it, is, to, and, of,
# Nearest to who: he, his, him, himself, gave, had, did, death,
# Nearest to behind: out, down, back, up, with, forward, off, pulled,
# Nearest to writers: authors, literature, literary, poets, novelists, works, fiction, author,
# Nearest to construction: largest, facilities, transport, roads, located, transportation, building, operates,
# Nearest to grand: royal, st, duke, was, town, palace, windsor, youngest,
# Nearest to stage: getting, best, successful, movies, scene, movie, a, film,
# Nearest to scale: scales, electric, higher, range, than, less, more, possible,
# Nearest to paris: french, du, de, la, france, louis, charles, fran,
# Nearest to animals: animal, humans, eat, species, human, mammals, insects, fish,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.6675 0.0321 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6039 0.0310 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6897 0.0312 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.6689 0.0313 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7734 0.0311 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.6785 0.0313 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.7026 0.0310 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6543 0.0312 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.7315 0.0311 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7614 0.0310 sec/batch
# Nearest to other: some, and, from, variety, its, it, as, are,
# Nearest to new: the, was, early, first, york, included, s, on,
# Nearest to than: be, it, are, very, have, to, less, more,
# Nearest to is: be, this, are, a, which, to, or, it,
# Nearest to called: is, a, are, other, usually, then, both, into,
# Nearest to after: took, had, was, he, when, returned, again, against,
# Nearest to where: point, then, number, times, a, the, this, is,
# Nearest to who: his, he, him, did, was, later, her, had,
# Nearest to behind: out, off, when, back, up, pulled, down, turn,
# Nearest to writers: poets, literature, novelists, literary, authors, bibliography, books, reader,
# Nearest to construction: facilities, operates, transportation, largest, rail, transport, connecting, located,
# Nearest to grand: royal, town, ii, st, windsor, palace, prince, british,
# Nearest to stage: best, films, series, scene, film, movie, movies, productions,
# Nearest to scale: scales, range, measuring, are, than, very, electric, distance,
# Nearest to paris: le, la, french, du, de, france, louis, maria,
# Nearest to animals: animal, humans, species, mammals, prey, habits, skin, eat,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5957 0.0322 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.6865 0.0313 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7213 0.0311 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6574 0.0312 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7202 0.0313 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6370 0.0313 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.5749 0.0311 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.6808 0.0313 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.7281 0.0311 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6539 0.0314 sec/batch
# Nearest to other: some, have, or, that, many, this, these, its,
# Nearest to new: york, s, at, in, on, one, nine, the,
# Nearest to than: less, however, be, it, this, or, been, more,
# Nearest to is: are, or, this, it, be, thus, all, can,
# Nearest to called: is, these, which, into, or, it, a, are,
# Nearest to after: was, had, the, until, to, last, returned, by,
# Nearest to where: is, a, the, it, times, on, then, with,
# Nearest to who: him, he, his, had, was, did, whom, to,
# Nearest to behind: down, out, pulled, move, with, keep, face, struck,
# Nearest to writers: poets, literary, literature, author, novelists, essays, authors, books,
# Nearest to construction: transport, facilities, largest, connecting, transportation, building, its, small,
# Nearest to grand: auto, home, royal, theft, city, opened, windsor, new,
# Nearest to stage: scene, getting, played, series, productions, appearances, movie, goes,
# Nearest to scale: scales, slightly, higher, range, large, small, approximately, smaller,
# Nearest to paris: de, le, du, fran, louis, la, architect, french,
# Nearest to animals: animal, mammals, humans, plants, insects, prey, species, organisms,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6504 0.0319 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.6919 0.0308 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5497 0.0312 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.5972 0.0312 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6071 0.0312 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6259 0.0314 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.6826 0.0313 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7803 0.0313 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.7984 0.0310 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5355 0.0309 sec/batch
# Nearest to other: more, to, their, many, such, most, are, for,
# Nearest to new: york, united, in, of, by, on, included, nine,
# Nearest to than: more, less, are, to, it, be, for, compared,
# Nearest to is: are, there, it, as, these, to, can, an,
# Nearest to called: is, an, the, and, of, a, into, as,
# Nearest to after: was, had, until, soon, became, were, turned, who,
# Nearest to where: the, which, an, at, as, a, from, is,
# Nearest to who: his, had, him, after, did, were, gave, was,
# Nearest to behind: down, out, off, long, move, with, a, they,
# Nearest to writers: novelists, births, authors, literature, bibliography, essays, biography, poets,
# Nearest to construction: building, railways, adjacent, rail, railway, across, transport, operates,
# Nearest to grand: until, royal, mayor, joined, new, serving, british, palace,
# Nearest to stage: best, audiences, film, films, debut, audience, appearances, movie,
# Nearest to scale: small, scales, large, lower, slightly, higher, sharp, overall,
# Nearest to paris: de, france, french, la, du, le, portrait, st,
# Nearest to animals: animal, humans, species, mammals, insects, feeding, plants, prey,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.6061 0.0320 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6640 0.0314 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5126 0.0310 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5684 0.0314 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6202 0.0312 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.6122 0.0311 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6859 0.0156 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5850 0.0313 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6226 0.0312 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.6129 0.0311 sec/batch
# Nearest to other: is, as, many, to, these, which, and, a,
# Nearest to new: york, united, america, on, s, states, first, washington,
# Nearest to than: is, from, less, it, more, few, with, other,
# Nearest to is: a, as, are, other, also, from, and, the,
# Nearest to called: is, are, these, form, it, a, exist, example,
# Nearest to after: was, had, in, until, the, when, took, during,
# Nearest to where: a, an, if, which, is, this, with, thus,
# Nearest to who: his, he, was, had, himself, gave, her, their,
# Nearest to behind: down, off, just, when, back, forward, move, enough,
# Nearest to writers: authors, novelists, literature, books, poets, literary, works, bibliography,
# Nearest to construction: transportation, largest, major, roads, ports, railways, transport, port,
# Nearest to grand: opens, british, duke, one, car, windsor, tennis, opened,
# Nearest to stage: best, audience, audiences, films, when, performance, attention, debut,
# Nearest to scale: scales, note, measuring, key, notes, sizes, intervals, major,
# Nearest to paris: de, la, france, fran, marie, louis, philippe, st,
# Nearest to animals: animal, humans, species, insects, plants, mammals, prey, sheep,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5434 0.0319 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6063 0.0309 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5446 0.0311 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.4815 0.0312 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5817 0.0312 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.6176 0.0311 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5370 0.0311 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4086 0.0311 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.5012 0.0313 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.4548 0.0311 sec/batch
# Nearest to other: and, as, of, the, many, are, have, such,
# Nearest to new: at, york, included, one, by, including, city, founded,
# Nearest to than: are, and, to, which, the, less, between, this,
# Nearest to is: are, can, form, a, this, there, be, and,
# Nearest to called: are, is, a, known, other, it, form, and,
# Nearest to after: had, were, before, was, took, he, during, when,
# Nearest to where: a, the, to, this, it, and, is, which,
# Nearest to who: had, did, he, his, himself, their, among, after,
# Nearest to behind: turned, out, back, down, after, put, shot, move,
# Nearest to writers: literature, authors, literary, novelists, bibliography, philosophers, writings, reader,
# Nearest to construction: transportation, operates, largest, facilities, adjacent, rail, city, roads,
# Nearest to grand: tennis, opened, was, at, june, joined, opens, mayors,
# Nearest to stage: best, films, film, debut, audiences, success, successful, movie,
# Nearest to scale: scales, measuring, more, higher, electric, much, measured, from,
# Nearest to paris: france, le, de, du, la, philippe, fran, marie,
# Nearest to animals: animal, species, humans, insects, plants, prey, skin, organisms,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5528 0.0321 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.4895 0.0310 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5070 0.0309 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5276 0.0311 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.4917 0.0312 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6056 0.0310 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4776 0.0312 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4862 0.0312 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5404 0.0314 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.5187 0.0312 sec/batch
# Nearest to other: the, and, these, has, are, of, which, a,
# Nearest to new: york, first, early, the, also, home, and, including,
# Nearest to than: it, more, amount, less, have, is, some, a,
# Nearest to is: all, a, are, an, it, this, which, as,
# Nearest to called: which, is, known, all, different, as, it, another,
# Nearest to after: had, was, took, returned, again, before, later, turned,
# Nearest to where: is, then, a, above, the, it, can, all,
# Nearest to who: did, to, had, their, himself, was, before, he,
# Nearest to behind: down, out, off, back, forward, pulled, once, move,
# Nearest to writers: literature, novelists, literary, authors, poets, biography, author, essays,
# Nearest to construction: transportation, operates, largest, facilities, industries, located, roads, building,
# Nearest to grand: opened, tennis, youngest, las, mayor, masters, one, built,
# Nearest to stage: best, successful, film, plays, appeared, scene, s, audiences,
# Nearest to scale: scales, measuring, measured, amount, tuned, higher, energy, approximately,
# Nearest to paris: de, le, du, fran, france, marie, french, la,
# Nearest to animals: animal, humans, species, insects, predators, prey, mammals, breeding,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5256 0.0322 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5288 0.0314 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4290 0.0312 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5229 0.0311 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5671 0.0319 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.4760 0.0320 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.4571 0.0322 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5068 0.0313 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4302 0.0314 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.3955 0.0313 sec/batch
# Nearest to other: as, such, are, for, has, of, in, these,
# Nearest to new: first, on, york, s, states, post, incorporated, the,
# Nearest to than: more, it, for, are, but, has, less, be,
# Nearest to is: a, this, are, as, which, can, it, an,
# Nearest to called: which, is, a, it, these, of, thus, from,
# Nearest to after: was, had, ended, until, remained, took, the, before,
# Nearest to where: the, a, in, s, then, to, at, all,
# Nearest to who: his, whom, he, had, himself, did, before, them,
# Nearest to behind: off, down, out, move, would, after, again, away,
# Nearest to writers: literary, literature, novelists, authors, works, poets, biography, essays,
# Nearest to construction: roads, large, at, building, built, main, buildings, across,
# Nearest to grand: opened, mayor, junior, city, royal, new, joined, mayors,
# Nearest to stage: getting, audience, play, success, successful, off, attention, get,
# Nearest to scale: scales, higher, measuring, measured, amount, gas, than, quantities,
# Nearest to paris: de, french, le, france, du, fran, philippe, la,
# Nearest to animals: animal, species, humans, mammals, insects, plants, predators, breeding,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4482 0.0322 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4802 0.0312 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5158 0.0315 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5889 0.0321 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6826 0.0312 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.3807 0.0307 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.4814 0.0313 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.4829 0.0315 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3114 0.0310 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4546 0.0310 sec/batch
# Nearest to other: are, a, to, has, more, which, some, especially,
# Nearest to new: york, on, in, first, was, by, and, the,
# Nearest to than: more, less, the, has, are, also, which, its,
# Nearest to is: can, called, are, above, this, a, form, example,
# Nearest to called: is, the, a, example, corresponding, are, also, an,
# Nearest to after: was, had, took, war, returned, were, during, ended,
# Nearest to where: is, given, a, which, then, here, this, if,
# Nearest to who: his, he, whom, did, him, was, met, saw,
# Nearest to behind: off, down, out, back, pick, s, going, door,
# Nearest to writers: novelists, authors, fiction, poets, literary, literature, births, essays,
# Nearest to construction: building, roads, built, buildings, adjacent, large, connecting, hub,
# Nearest to grand: town, opened, mayors, city, towns, county, cities, france,
# Nearest to stage: best, audience, film, performance, performing, audiences, comedy, actors,
# Nearest to scale: notes, higher, small, relatively, scales, note, also, large,
# Nearest to paris: de, france, la, louis, du, xiv, famous, philippe,
# Nearest to animals: animal, species, insects, humans, birds, plants, predators, mammals,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4368 0.0324 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.4141 0.0312 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
